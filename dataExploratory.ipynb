# %% [markdown]
# ## 資料探索

# %% [markdown]
# ## iris資料
# 150 obs, 4 features
# * Sepal length 萼片
# * Sepal width
# * Petal length 花瓣
# * petal width
# * 種類

# %%
import pandas as pd
import matplotlib.pyplot as plt
iris = pd.read_csv('data/iris/iris.csv', index_col=0)
print(iris.shape)
# Out:
# (149, 4)

# %%
iris.head() #what're problems?
# Out:
#      3.5  1.4  0.2  Iris-setosa
# 5.1
# 4.9  3.0  1.4  0.2  Iris-setosa
# 4.7  3.2  1.3  0.2  Iris-setosa
# 4.6  3.1  1.5  0.2  Iris-setosa
# 5.0  3.6  1.4  0.2  Iris-setosa
# 5.4  3.9  1.7  0.4  Iris-setosa

# %%
iris = pd.read_csv('data/iris/iris.csv', header=None) #header

# %%
iris.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
iris.names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']

# %%
iris = pd.read_csv('data/iris/iris.csv', header=None, names=iris.names) #column names

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
#line plot
iris.plot(x='sepal_length', y='sepal_width') #無法看出什麼？
plt.show()

# %%
#scatter plot
iris.plot(x='sepal_length', y='sepal_width', kind='scatter')
plt.xlabel('sepal length (cm)')
plt.ylabel('sepal width (cm)')
plt.show()

# %%
#box plot
iris.plot(y='sepal_width', kind='box')
plt.ylabel('sepal width (cm)')
plt.show()

# %% [markdown]
# box plot的意義？

# %%
#histogram plot 直方圖 -- 機率分布函數、累積分布函數
iris.plot(y='sepal_width', kind='hist')
plt.ylabel('sepal width (cm)')
plt.show()

# %% [markdown]
# * bins(int)
# * range(tuple)
# * normed(boolean)
# * cumulative(boolean)

# %%
iris.plot(y='sepal_length', kind='hist',
         bins=30, range=(4,8), normed=True)
plt.xlabel('sepal length (cm)')
plt.show()

# %%
iris.plot(y='sepal_length', kind='hist',
         bins=30, range=(4,8), cumulative=True, normed=True)
plt.xlabel('sepal length (cm)')
plt.show()

# %%
iris.hist(bins=30, normed=True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x116bd6fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116f4fa58>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x116f56dd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116e2d390>]], dtype=object)

# %%
plt.show()

# %%
iris.hist(bins=30, normed=True, cumulative=True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1173e07f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1174455f8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1174b2b38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117513f98>]], dtype=object)

# %%
plt.show()
