# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("~/Desktop/crimeTypeTest.csv")

# %%
df.head()
# Out:
#            crime_ID  crime_type03
# 0  FFFFFFFFBA677FC9            13
# 1  FFFFFFFFD8DB4141            13
# 2  FFFFFFFFDB51030D            14
# 3  FFFFFFFFA4AD8487            14
# 4  FFFFFFFFD7183C0D            13

# %%
df.groupby("crime_ID").count()
# Out:
#                   crime_type03
# crime_ID
# 10038E9E                     1
# 1012A968                     1
# 101BC0BC                     1
# 101F8884                     1
# 1023F80                      1
# 10254F50                     1
# 1038A5DA                     1
# 104823DF                     1
# 10489B35                     1
# 10568A52                     1
# 1077BCA4                     1
# 10AB528D                     1
# 10ABBA92                     1
# 10BBBE92                     1
# 10BC3581                     1
# 10CE66E1                     1
# 10F57EE9                     1
# 1104A6A6                     1
# 11154824                     1
# 11210C55                     1
# 112FFE99                     1
# 114999F3                     1
# 114E823A                     1
# 11604A08                     1
# 1178ED77                     1
# 119FA0ED                     1
# 11A0D19F                     1
# 11A4276D                     1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3484 entries, 0 to 3483
# Data columns (total 2 columns):
# crime_ID        3484 non-null object
# crime_type03    3484 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 54.5+ KB

# %%
df.describe()
# Out:
#        crime_type03
# count   3484.000000
# mean      11.308553
# std        2.690959
# min        1.000000
# 25%        8.000000
# 50%       13.000000
# 75%       13.000000
# max       14.000000

# %%
x = pd.unique(df["crime_ID"])

# %%
print(x)
# Out:
# ['FFFFFFFFBA677FC9' 'FFFFFFFFD8DB4141' 'FFFFFFFFDB51030D' ...,
#  'FFFFFFFF97CB4C47' '44525ECA' 'FFFFFFFFDFA34CF5']

# %%
len(x)
# Out:
# 3472

# %%
df.shape
# Out:
# (3484, 2)

# %%
df.groupby("crime_type03").count()
# Out:
#               crime_ID
# crime_type03
# 1                   16
# 2                   16
# 3                   24
# 5                   20
# 8                  869
# 9                  165
# 10                 182
# 11                 140
# 13                1346
# 14                 706

# %%
df1 = pd.read_csv("~/Desktop/crimeType.csv")

# %%
df1.groupby("crime_type03").count()
# Out:
#               crime_ID
# crime_type03
# 1                 7935
# 2                 7653
# 3                 6186
# 5                 4695
# 8               183975
# 9                20765
# 10               35633
# 11               38846
# 13              211895
# 14              113616

# %%
df1.shape
# Out:
# (631199, 2)

# %%
x=df1.groupby("crime_type03").count()

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame
