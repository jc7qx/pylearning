# %% [markdown]
# ### Python科學繪圖
# * [Matplotlib](http://matplotlib.org/index.html): 2D繪圖
# * [Seaborn](http://seaborn.pydata.org/): 以matplotlib為基礎，提供統計圖形繪製
# * [Bokeh](http://bokeh.pydata.org/en/latest/): Python互動式視覺函式庫
# * [Plotly](https://plot.ly/python/): 高品質互動式圖形Python函式庫

# %% [markdown]
# ### 簡單基本折線圖

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
plt.plot([-1, -4.5, 16, 23])
plt.show()

# %% [markdown]
# ### 點線圖

# %% [markdown]
# "-"：線，"b"：blue ([line style](https://matplotlib.org/devdocs/gallery/lines_bars_and_markers/line_styles_reference.html))
#
# "^"：點圖標，"r"：red

# %%
plt.plot([-1, -4.5, 16, 23], "-b")
plt.plot([-1, -4.5, 16, 23], "^r")
plt.show()

# %%
import matplotlib.pyplot as plt
days = range(0,22,3)
print(days)
cel_values = [25.6, 24.1, 26.7, 28.3, 27.5, 30.5, 32.8, 33.1]
plt.plot(days, cel_values)
plt.plot(days, cel_values, "og")
plt.show()
# Out:
# range(0, 22, 3)

# %%
plt.plot(days, cel_values, "-r")
plt.show()

# %%
import matplotlib.pyplot as plt
days = list(range(1,9))
celsius_min = [19.6, 24.1, 26.7, 28.3, 27.5, 30.5, 32.8, 33.1]
celsius_max = [24.8, 28.9, 31.3, 33.0, 34.9, 35.6, 38.4, 39.2]
plt.xlabel('Day') # x軸標題
plt.ylabel('Degrees Celsius') # y軸標題
plt.plot(days, celsius_min,
         days, celsius_min, "om")
plt.plot(days, celsius_max, 
         days, celsius_max, "og")
plt.show()

# %%
days = list(range(1,9))
celsius_min = [19.6, 24.1, 26.7, 28.3, 27.5, 30.5, 32.8, 33.1]
celsius_max = [24.8, 28.9, 31.3, 33.0, 34.9, 35.6, 38.4, 39.2]
plt.xlabel('Day')
plt.ylabel('Degrees Celsius')
plt.plot(days, celsius_min,
         days, celsius_min, "om",
         days, celsius_max, 
         days, celsius_max, "or")
print("The current limits for the axes are:")        
print(plt.axis())
print("We set the axes to the following values:")
xmin, xmax, ymin, ymax = 0, 10, 14, 45
print(xmin, xmax, ymin, ymax)
plt.axis([xmin, xmax, ymin, ymax]) #x, y軸的數值範圍
plt.show()
# Out:
# The current limits for the axes are:
# (0.64999999999999991, 8.3499999999999996, 18.620000000000001, 40.18)
# We set the axes to the following values:
# 0 10 14 45

# %%
import numpy as np
import matplotlib.pyplot as plt
X = np.linspace(0, 2 * np.pi, 50, endpoint=True)
F = np.sin(X)
plt.plot(X,F)
startx, endx = -0.1, 2*np.pi + 0.1
starty, endy = -1.1, 1.1
plt.axis([startx, endx, starty, endy])
plt.show()

# %%
import matplotlib.pyplot as plt
X = np.linspace(-2 * np.pi, 2 * np.pi, 50, endpoint=True) #定義X範圍
F1 = 3 * np.sin(X)                                        #計算F1值
F2 = np.sin(2*X)                                          #計算F2值
F3 = 0.3 * np.sin(X)                                      #計算F3值
startx, endx = -2 * np.pi - 0.1, 2*np.pi + 0.1            #定義X軸的顯示範圍
starty, endy = -3.1, 3.1                                  #定義y軸的顯示範圍
plt.axis([startx, endx, starty, endy])                    #設定X,y軸的顯示範圍
plt.plot(X,F1, "g")                                       #畫出F1的圖形
plt.plot(X,F2, "m")                                       #畫出F2的圖形
plt.plot(X,F3, "r")                                       #畫出F3的圖形
plt.show()

# %%
#設定不同的line style
import matplotlib.pyplot as plt
X = np.linspace(0, 2 * np.pi, 50, endpoint=True)
F1 = 3 * np.sin(X)
F2 = np.sin(2*X)
F3 = 0.3 * np.sin(X)
F4 = np.cos(X)
plt.plot(X, F1, color="blue", linewidth=2.5, linestyle="-", label="F1")
plt.plot(X, F2, color="red", linewidth=1.5, linestyle="--", label="F2")
plt.plot(X, F3, color="green", linewidth=2, linestyle=":", label="F3")
plt.plot(X, F4, color="grey", linewidth=2, linestyle="-.", label="F4")
plt.legend(loc='lower left', frameon=False)
plt.show()

# %%
#設定不同的line style
import matplotlib.pyplot as plt
X = np.linspace(-np.pi, np.pi, 50, endpoint=True)
F1 = 3 * np.sin(X)
F2 = np.sin(2*X)
F3 = 0.3 * np.sin(X)
F4 = np.cos(X)
#畫圖
plt.plot(X, F1, color="blue", linewidth=2.5, linestyle="-", label="F1")
plt.plot(X, F2, color="red", linewidth=1.5, linestyle="--", label="F2")
plt.plot(X, F3, color="green", linewidth=2, linestyle=":", label="F3")
plt.plot(X, F4, color="grey", linewidth=2, linestyle="-.", label="F4")
#設定x, y軸位置
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))
#設定圖例
plt.legend(loc='upper left', frameon=False)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
n = 256
X = np.linspace(-np.pi,np.pi,n,endpoint=True)
Y = np.sin(2*X)
plt.plot (X, Y, color='blue', alpha=1.00)
plt.fill_between(X, 0, Y, color='blue', alpha=.1)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
n = 256
X = np.linspace(-np.pi,np.pi,n,endpoint=True)
Y = np.sin(2*X)
plt.plot (X, Y, color='blue', alpha=1.00)
plt.fill_between(X, Y, 1, color='blue', alpha=.1)
plt.show()

# %% [markdown]
# ### History plot

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab

mu, sigma = 100, 15
x = mu + sigma*np.random.randn(10000)
n, bins, patches = plt.hist(x, 50, normed=1, facecolor='green', alpha=0.75, width=1.7)

y = mlab.normpdf( bins, mu, sigma)
l = plt.plot(bins, y, 'r--', linewidth=1)

plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()

# %% [markdown]
# ### Bar Chart

# %%
import numpy as np
import matplotlib.pyplot as plt


N = 5
menMeans = (20, 35, 30, 35, 27)
womenMeans = (25, 32, 34, 20, 25)
menStd = (2, 3, 4, 1, 2)
womenStd = (3, 5, 2, 3, 3)
ind = np.arange(N)    # the x locations for the groups
width = 0.35       # the width of the bars: can also be len(x) sequence

p1 = plt.bar(ind, menMeans, width, yerr=menStd)
p2 = plt.bar(ind, womenMeans, width,
             bottom=menMeans, yerr=womenStd)

plt.ylabel('Scores')
plt.title('Scores by group and gender')
plt.xticks(ind, ('G1', 'G2', 'G3', 'G4', 'G5'))
plt.yticks(np.arange(0, 81, 10))
plt.legend((p1[0], p2[0]), ('Men', 'Women'))


plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
#data
salary = [47, 48, 49, 50, 51, 52, 53, 54, 56, 57, 60]
frequency = [4, 1, 3, 5, 8, 10, 0, 5, 2, 3, 1]

plt.bar(salary,frequency)
plt.yticks(range(0,11))
plt.xticks(range(47,61))
plt.show()

# %% [markdown]
# ### Scatter Plots

# %%
plt.scatter(salary,frequency, c='red')
plt.show()

# %%
frepie = [x/sum(frequency)*100 for x in frequency]
labels =[str(x) for x in salary]
plt.title("Pie chart for salary", bbox={'facecolor':'0.8', 'pad':5})
plt.pie(frepie, labels=labels, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1a12eeaa20>,
#   <matplotlib.patches.Wedge at 0x1a12ef2c18>,
#   <matplotlib.patches.Wedge at 0x1a12ef9e10>,
#   <matplotlib.patches.Wedge at 0x1a12fde048>,
#   <matplotlib.patches.Wedge at 0x1a12fe5240>,
#   <matplotlib.patches.Wedge at 0x1a12fee438>,
#   <matplotlib.patches.Wedge at 0x1a12ff5630>,
#   <matplotlib.patches.Wedge at 0x1a12fff828>,
#   <matplotlib.patches.Wedge at 0x1a13007a20>,
#   <matplotlib.patches.Wedge at 0x1a13012c18>,
#   <matplotlib.patches.Wedge at 0x1a12f69a58>],
#  [<matplotlib.text.Text at 0x1a12ef21d0>,
#   <matplotlib.text.Text at 0x1a12ef93c8>,
#   <matplotlib.text.Text at 0x1a12f015c0>,
#   <matplotlib.text.Text at 0x1a12fde7b8>,
#   <matplotlib.text.Text at 0x1a12fe59b0>,
#   <matplotlib.text.Text at 0x1a12feeba8>,
#   <matplotlib.text.Text at 0x1a12ff5da0>,
#   <matplotlib.text.Text at 0x1a12ffff98>,
#   <matplotlib.text.Text at 0x1a130121d0>,
#   <matplotlib.text.Text at 0x1a130193c8>,
#   <matplotlib.text.Text at 0x1a12f636a0>],
#  [<matplotlib.text.Text at 0x1a12ef26a0>,
#   <matplotlib.text.Text at 0x1a12ef9898>,
#   <matplotlib.text.Text at 0x1a12f01a90>,
#   <matplotlib.text.Text at 0x1a12fdec88>,
#   <matplotlib.text.Text at 0x1a12fe5e80>,
#   <matplotlib.text.Text at 0x1a12ff50b8>,
#   <matplotlib.text.Text at 0x1a12fff2b0>,
#   <matplotlib.text.Text at 0x1a130074a8>,
#   <matplotlib.text.Text at 0x1a130126a0>,
#   <matplotlib.text.Text at 0x1a13019898>,
#   <matplotlib.text.Text at 0x1a12f5d710>])

# %%
import matplotlib.pyplot as plt
import numpy as np


np.random.seed(10)
collectn_1 = np.random.normal(100, 10, 200)
collectn_2 = np.random.normal(80, 30, 200)
collectn_3 = np.random.normal(90, 20, 200)
collectn_4 = np.random.normal(70, 25, 200)

data_to_plot = [collectn_1, collectn_2, collectn_3, collectn_4]

fig = plt.figure(1, figsize=(9, 6))
ax = fig.add_subplot(111)
bp = ax.boxplot(data_to_plot)

ax.set_xticklabels(['Sample1', 'Sample2', 'Sample3', 'Sample4'])
ax.get_xaxis().tick_bottom()
ax.get_yaxis().tick_left()

plt.show()

# %% [markdown]
# ## Seaborn

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
from scipy.stats import spearmanr
sns.set(style="white", color_codes=True)

# %%
trade = pd.read_csv('/users/mac/desktop/yunho1.csv')

# %%
trade.head()
# Out:
#          lat        long class
# 0  25.004546  121.518724    普通
# 1  24.999301  121.519173    機車
# 2  24.999301  121.519173    機車
# 3  25.009178  121.520484    普通
# 4  25.012061  121.514884    機車

# %%
g = sns.jointplot(x = "lat", y = "long", xlim=(24.995, 25.02),ylim=(121.50, 121.53),data=trade)

# %%
g = sns.jointplot(x = "lat", y = "long",xlim=(24.995, 25.02),ylim=(121.50, 121.53),data=trade, kind="scatter")

# %%
g = sns.jointplot(x = "lat", y = "long", xlim=(24.995, 25.02),ylim=(121.50, 121.53),data=trade, kind="hex")

# %%
g = sns.jointplot(x = "lat", y = "long", xlim=(24.995, 25.02),ylim=(121.50, 121.53),data=trade, kind="kde", space=0, color='g')

# %%
sns.lmplot(x="long", y = "lat",data=trade, fit_reg=False, hue="class", scatter_kws={"marker":"D", "s":30})

# %%
trade.shape
# Out:
# (3470, 3)

# %%
print(trade["lat"])
# Out:
# 0       25.004546
# 1       24.999301
# 2       24.999301
# 3       25.009178
# 4       25.012061
# 5       25.003893
# 6       25.008479
# 7       25.006176
# 8       24.996263
# 9       25.008573
# 10      25.013930
# 11      25.003577
# 12      25.006389
# 13      25.004856
# 14      25.004415
# 15      24.999481
# 16      25.000769
# 17      25.004599
# 18      25.012277
# 19      25.015407
# 20      25.009870
# 21      25.006623
# 22      25.008110
# 23      25.007858
# 24      25.012142
# 25      25.009914
# 26      25.005765
# 27      25.008613
# 28      25.009450
# 29      24.997790
#           ...
# 3440    24.995784
# 3441    25.010352
# 3442    25.010478
# 3443    25.004153
# 3444    25.018077
# 3445    25.013848
# 3446    25.010913
# 3447    25.046004
# 3448    24.997351
# 3449    25.009980
# 3450    24.998607
# 3451    25.006992
# 3452          NaN
# 3453    25.003868
# 3454    25.003491
# 3455    25.010973
# 3456    25.003038
# 3457    25.014752
# 3458    25.011089
# 3459    24.997002
# 3460    25.011994
# 3461    25.013333
# 3462    25.005883
# 3463    25.000404
# 3464    25.016228
# 3465    25.004605
# 3466    25.010913
# 3467    25.013002
# 3468    24.996855
# 3469    25.009660
# Name: lat, Length: 3470, dtype: float64

# %%
crime = [trade["long"],trade["lat"]]

# %%
g=sns.kdeplot(crime)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-113-e12d3d48b9f0> in <module>()
# ----> 1 g=sns.kdeplot(crime)
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/distributions.py in kdeplot(data, data2, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     613         warn = True
#     614         bivariate = True
# --> 615         x, y = data.T
#     616     elif isinstance(data, pd.DataFrame) and np.ndim(data) > 1:
#     617         warn = True
#
# ValueError: too many values to unpack (expected 2)

# %%
crime
# Out:
# [0       121.518724
#  1       121.519173
#  2       121.519173
#  3       121.520484
#  4       121.514884
#  5       121.525818
#  6       121.509789
#  7       121.514473
#  8       121.522260
#  9       121.517738
#  10      121.517848
#  11      121.513599
#  12      121.525590
#  13      121.517330
#  14      121.512747
#  15      121.519497
#  16      121.521060
#  17      121.519281
#  18      121.521405
#  19      121.512579
#  20      121.502982
#  21      121.520372
#  22      121.508452
#  23      121.520515
#  24      121.521845
#  25      121.521458
#  26      121.509162
#  27      121.513931
#  28      121.505627
#  29      121.525594
#             ...
#  3440    121.517860
#  3441    121.514989
#  3442    121.522505
#  3443    121.523894
#  3444    121.513001
#  3445    121.514945
#  3446    121.512044
#  3447    121.553226
#  3448    121.519776
#  3449    121.520827
#  3450    121.519973
#  3451    121.523901
#  3452           NaN
#  3453    121.522439
#  3454    121.523486
#  3455    121.522865
#  3456    121.527081
#  3457    121.516723
#  3458    121.517682
#  3459    121.515520
#  3460    121.515149
#  3461    121.512576
#  3462    121.521703
#  3463    121.515182
#  3464    121.516416
#  3465    121.523161
#  3466    121.512044
#  3467    121.522281
#  3468    121.520006
#  3469    121.516713
#  Name: long, Length: 3470, dtype: float64, 0       25.004546
#  1       24.999301
#  2       24.999301
#  3       25.009178
#  4       25.012061
#  5       25.003893
#  6       25.008479
#  7       25.006176
#  8       24.996263
#  9       25.008573
#  10      25.013930
#  11      25.003577
#  12      25.006389
#  13      25.004856
#  14      25.004415
#  15      24.999481
#  16      25.000769
#  17      25.004599
#  18      25.012277
#  19      25.015407
#  20      25.009870
#  21      25.006623
#  22      25.008110
#  23      25.007858
#  24      25.012142
#  25      25.009914
#  26      25.005765
#  27      25.008613
#  28      25.009450
#  29      24.997790
#            ...
#  3440    24.995784
#  3441    25.010352
#  3442    25.010478
#  3443    25.004153
#  3444    25.018077
#  3445    25.013848
#  3446    25.010913
#  3447    25.046004
#  3448    24.997351
#  3449    25.009980
#  3450    24.998607
#  3451    25.006992
#  3452          NaN
#  3453    25.003868
#  3454    25.003491
#  3455    25.010973
#  3456    25.003038
#  3457    25.014752
#  3458    25.011089
#  3459    24.997002
#  3460    25.011994
#  3461    25.013333
#  3462    25.005883
#  3463    25.000404
#  3464    25.016228
#  3465    25.004605
#  3466    25.010913
#  3467    25.013002
#  3468    24.996855
#  3469    25.009660
#  Name: lat, Length: 3470, dtype: float64]
