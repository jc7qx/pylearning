# %% [markdown]
# ## Python科學繪圖
# Python程式語言提供幾個繪圖套件，**[Matplotlib](http://matplotlib.org/index.html)**提供二維繪製圖表功能，使用者可以很容易用來建立資料視覺化應用。**[Seaborn](http://seaborn.pydata.org/)** 以matplotlib為基礎，提供統計圖形繪製，**[Bokeh](http://bokeh.pydata.org/en/latest/)** 是一種互動式視覺呈現的python套件，及**[Plotly](https://plot.ly/python/)** 是一種高品質互動式圖形Python套件庫。
#
# **<center>此筆記以matplotlib為主</center>**
#
# * [pyplot](#pyplot)
# * [matplotlib基本繪圖基礎](#matplotlib基本繪圖基礎)
#     * [圖形尺寸](#圖形尺寸、解析度)
#     * [subplot](#subplot)
#     * [顏色、線寬、線型](#顏色、線寬、線型)
#     * [資料範圍、座標刻度、座標軸標籤](#資料範圍、座標刻度、座標軸標籤)
#     * [圖例](#圖例)
#     * [塗色](#塗色)
# * [統計圖](#統計圖)
#     * [line plot](#line-plot)
#     * [History plot](#History-plot)
#     * [scatter plot](#Scatter-Plots)
#     * [bar chart](#bar-chart)
#     * [pie chart](#pie-chart)
#     * [box plot](#box-plot)
# * [文字處理](#text)
#     * [中文字型處理](#中文字型處理)

# %% [markdown]
# ## pyplot
#
# pyplot提供一個介面來使用matplotlib的物件導向繪圖程式庫，pyplot的設計與matlab非常接近。使用pyplot前必須先導入程式庫。

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# 為要在Jupyter notebook中與繪圖環境互動，可以執行以下的設定

# %%
# %matplotlib inline

# %% [markdown]
# ## matplotlib基本繪圖基礎
#
# Matplotlib提供預設的繪圖參數設定，使用者也可以進一步控制繪圖的屬性，如圖形大小、線寬、類型、顏色、坐標軸、格線...，以及文字及字型屬型。

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
plt.plot([-1, -4.5, 16, 23])
plt.show()

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
plt.plot([-1, -4.5, 16, 23])
plt.show()

# %% [markdown]
# * ### 圖形尺寸、解析度

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 5), dpi=80)
line=plt.plot([-1, -4.5, 16, 23])
plt.setp(line) #顯示所有line的屬性
# Out:
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array
#   alpha: float
#   animated: bool
#   antialiased: bool
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: [(`~matplotlib.path.Path`, `.Transform`) | `.Patch` | None]
#   color: color
#   contains: callable
#   dash_capstyle: {'butt', 'round', 'projecting'}
#   dash_joinstyle: {'miter', 'round', 'bevel'}
#   dashes: sequence of floats (on/off ink in points) or (None, None)
#   drawstyle: {'default', 'steps', 'steps-pre', 'steps-mid', 'steps-post'}
#   figure: `.Figure`
#   fillstyle: {'full', 'left', 'right', 'bottom', 'top', 'none'}
#   gid: str
#   in_layout: bool
#   label: object
#   linestyle: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
#   linewidth: float
#   marker: unknown
#   markeredgecolor: color
#   markeredgewidth: float
#   markerfacecolor: color
#   markerfacecoloralt: color
#   markersize: float
#   markevery: unknown
# ...

# %% [markdown]
# * __subplot__

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.subplot(2, 1, 1) #subplot(211) is identical to subplot(2, 1, 1)
plt.plot([-1, -4.5, 16, 23], "gs-.") #"g^-" 代表綠色、三角形、實線
plt.subplot(2, 1, 2)
X = np.linspace(-np.pi, np.pi, 256, endpoint=True)
C = np.cos(X)
plt.plot(X, C,"r:") # "r" 代表紅色、需線
plt.show()

# %% [markdown]
# * ### 顏色、線寬、線型

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.subplot(2, 1, 1)
plt.plot([-1, -4.5, 16, 23], color="red", linewidth=2.0, marker='s', linestyle="-")
plt.subplot(2, 1, 2)
X = np.linspace(-np.pi, np.pi, 256, endpoint=True)
C = np.cos(X)
plt.plot(X, C,  color="blue", linewidth=3.0, linestyle="-.")
plt.show()

# %% [markdown]
# **線型與圖標形狀**
#
#
# |   character   |   description   |   character   |   description   |   character   |   description   |
# |:---------------:|:---------------|---------------|:---------------|---------------|:---------------|
# |   '-'     |     solid line style |   '--'    |     dashed line style |   '-.'    |     dash-dot line style  |
# |   ':'     |     dotted line style |   '.'     |     point marker |   ','     |     pixel marker |
# |   'o'     |     circle marker |   'v'     |     triangle_down marker |   '^'     |     triangle_up marker |
# |   '<'     |     triangle_left marker |   '>'     |     triangle_right marker |   '1'     |     tri_down marker |
# |   '2'     |     tri_up marker |   '3'     |     tri_left marker |   '4'     |     tri_right marker |
# |   's'     |     square marker |   'p'     |     pentagon marker |   '*'     |     star marker |
# |   'h'     |     hexagon1 marker |   'H'     |     hexagon2 marker |   '+'     |     plus marker |
# |   'x'     |     x marker |   'D'     |     diamond marker |   'd'     |     thin_diamond marker |
# |   ' \| '     |     vline marker |   '_'     |     hline marker |                         |                          |
#
# **顏色字母縮寫**
#
# |            字母縮寫   |            顏色                  |  字母縮寫   |            顏色                  |
# |:----------------------:|:----------------------------:|:----------------------:|:----------------------------:|
# |     ‘b’                       |                blue               |            ‘g’              |                  green            |
# |                 ‘r’             |              red                 |             ‘c’               |                    cyan            |
# |              ‘m’              |                     magenta  |                ‘y’             |              yellow             |
# |               ‘k’             |                 black             |             ‘w’                |                  white         |

# %% [markdown]
# * ### 資料範圍、座標刻度、座標軸標籤

# %%
import matplotlib.pyplot as plt
plt.subplot(2,1,1)
plt.plot([-1, -4.5, 16, 23])
plt.ylabel("y1 label")
plt.subplot(2,1,2)
plt.plot([-1, -4.5, 16, 23], color="red", linestyle=":")
plt.xlim(0, 3) # X軸資料顯示範圍
plt.xticks([0,1,2,3]) # X軸座標顯示
plt.ylim(-10, 30) # Y軸資料顯示範圍
plt.yticks([-10, -5, 0,5, 10,15, 20,25, 30]) # Y軸座標顯示
plt.xlabel("x2 label")
plt.ylabel("y2 label")
plt.show()

# %% [markdown]
# * ### 圖例
#
# `plt.legend(Loc)`

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5), dpi=80)

X = np.linspace(-np.pi, np.pi, 256,endpoint=True)
C = np.cos(X)
S = np.sin(X)

plt.plot(X, C, color="blue", linewidth=2.5, linestyle="-", label="cosine")
plt.plot(X, S, color="red", linewidth=2.5, linestyle="-",  label="sine")

ax = plt.gca()
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

plt.xlim(X.min() * 1.1, X.max() * 1.1)
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],
          [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])

plt.ylim(C.min() * 1.1, C.max() * 1.1)
plt.yticks([-1, +1],
          [r'$-1$', r'$+1$'])

plt.legend(loc='upper left') # 圖標放置位置左上
# best (0)upper right (1)upper left (2)lower left (3)lower right (4)right (5)
# center left (6)center right (7)lower center (8)upper center (9)center (10)

plt.show()

# %% [markdown]
# ### 二線同圖

# %%
import matplotlib.pyplot as plt
days = list(range(1,9))
celsius_min = [19.6, 24.1, 26.7, 28.3, 27.5, 30.5, 32.8, 33.1]
celsius_max = [24.8, 28.9, 31.3, 33.0, 34.9, 35.6, 38.4, 39.2]
plt.xlabel('Day')                      # x軸標題
plt.ylabel('Degrees Celsius') # y軸標題
plt.plot(days, celsius_min, "sm-")
plt.plot(days, celsius_max, "bo:")
plt.show()

# %%
days = list(range(1,9))
celsius_min = [19.6, 24.1, 26.7, 28.3, 27.5, 30.5, 32.8, 33.1]
celsius_max = [24.8, 28.9, 31.3, 33.0, 34.9, 35.6, 38.4, 39.2]
plt.xlabel('Day')
plt.ylabel('Degrees Celsius')
plt.plot(days, celsius_min,
         days, celsius_min, "bs-",
         days, celsius_max, "ro:"
)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
X = np.linspace(0, 2 * np.pi, 50, endpoint=True)
F = np.sin(X)
plt.plot(X,F,"--r")
startx, endx = -0.1, 2*np.pi + 0.1
starty, endy = -1.1, 1.1
plt.axis([startx, endx, starty, endy])
plt.show()

# %%
import matplotlib.pyplot as plt
X = np.linspace(-2 * np.pi, 2 * np.pi, 50, endpoint=True) #定義X範圍
F1 = 3 * np.sin(X)                                                     #計算F1值
F2 = np.sin(2*X)                                                       #計算F2值
F3 = 0.3 * np.sin(X)                                                 #計算F3值
F4 = np.cos(X)                                                          #計算F4值
startx, endx = -2 * np.pi - 0.1, 2*np.pi + 0.1      #定義X軸的顯示範圍
starty, endy = -3.1, 3.1                                           #定義y軸的顯示範圍
plt.axis([startx, endx, starty, endy])                    #設定X,y軸的顯示範圍
plt.plot(X,F1, "g")                                                   #畫出F1的圖形
plt.plot(X,F2, "m")                                                 #畫出F2的圖形
plt.plot(X,F3, "r")                                                   #畫出F3的圖形
plt.plot(X,F4, "b")                                                   #畫出F3的圖形
plt.show()

# %% [markdown]
# **練習：**請根據上個展示例子，畫出以下圖形。(需要設定線的形狀，顏色，及圖例)
# ![](pic/sin1.png)

# %% [markdown]
# * ### 塗色
#
# `matplotlib.fill(x,y)`<br>
# `matplotlib.fill_between(x,y1, y2)`

# %%
import matplotlib.pyplot as plt
import numpy as np

x = [0, 2, 5]
y1 = [1, 2.5, 3]
y2 = [2, 3, 4.5]
plt.plot(x, y1)
plt.plot(x,y2)
plt.fill(x, y1, color="yellow")
#plt.savefig("out.png")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = [0, 2, 5]
y1 = [1, 2.5, 3]
y2 = [2, 3, 4.5]
plt.plot(x, y1)
plt.plot(x,y2)
plt.fill_between(x, 1.5,y2, facecolor="pink", alpha=0.2)
#plt.savefig("out.png")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
 
x = np.arange(0.0, 4.0*np.pi, 0.01)
y = np.sin(x)
plt.plot(x, y)
 
plt.plot((x.min(),x.max()), (0,0))
 
# 設定座標軸標籤
plt.xlabel('x')
plt.ylabel('y')
 
# 填充指定區域
plt.fill_between(x,y, where=(2.3<x) & (x<4.3) | (x>10), facecolor='purple')
 
# 可以填充多次
plt.fill_between(x,y,where=(7<x) & (x<8), facecolor='green')
 
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
n = 256
X = np.linspace(-np.pi,np.pi,n,endpoint=True)
Y = np.sin(2*X)
plt.plot (X, Y, color='blue', alpha=1.00)
plt.fill_between(X,0,Y,color='blue', alpha=.1)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
n = 256
X = np.linspace(-np.pi,np.pi,n,endpoint=True)
Y = np.sin(2*X)
plt.plot (X, Y, color='blue', alpha=1.00)
plt.fill_between(X, Y, 1, color='blue', alpha=.1)
plt.show()

# %% [markdown]
# ## 統計圖
#
# * Line Plot
# * Bar Chart
# * Histogram Plot
# * Scatter Plot
# * Stack Plot
# * Pie Chart
# * Box Plot

# %% [markdown]
# ### Line plot

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# 一週溫度
x = np.arange(7)
th = np.array([23, 25, 27, 27, 25, 23, 19])
tl = np.array([18,17,17,18,19,17,17])

plt.plot(x, th, color="blue", linestyle="-", marker="^")
plt.plot(x, tl, color="red", linestyle=":", marker="s")

plt.xlabel("week days")
plt.ylabel("Temperture (c)")
plt.title("Weekly Tempertures")
plt.xticks(x, ['Sun','Mon', 'Tue', 'Wed', 'Thr', 'Fri', 'Sat'])

plt.show()

# %% [markdown]
# ### History plot

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab

mu, sigma = 100, 15
x = mu + sigma*np.random.randn(10000)
n, bins, patches = plt.hist(x, 50, normed=1, facecolor='green', alpha=0.75, width=1.7)

y = mlab.normpdf( bins, mu, sigma)
l = plt.plot(bins, y, 'r--', linewidth=1)

plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()
# Out:
# C:\Users\jc7qx\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: MatplotlibDeprecationWarning: scipy.stats.norm.pdf
#   if __name__ == '__main__':

# %% [markdown]
# ### Bar Chart

# %%
import numpy as np
import matplotlib.pyplot as plt
#data
salary = [47, 48, 49, 50, 51, 52, 53, 54, 56, 57, 60]
frequency = [4, 1, 3, 5, 8, 10, 0, 5, 2, 3, 1]

plt.bar(salary,frequency)
plt.yticks(range(0,11))
plt.xticks(range(47,61))
plt.xlabel("salary(x1000)")
plt.ylabel("number of employee")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


N = 5
menMeans = (20, 35, 30, 35, 27)
womenMeans = (25, 32, 34, 20, 25)
menStd = (2, 3, 4, 1, 2)
womenStd = (3, 5, 2, 3, 3)
ind = np.arange(N)    # the x locations for the groups
width = 0.35       # the width of the bars: can also be len(x) sequence

p1 = plt.bar(ind, menMeans, width, yerr=menStd)
p2 = plt.bar(ind, womenMeans, width,
             bottom=menMeans, yerr=womenStd)

plt.ylabel('Scores')
plt.title('Scores by group and gender')
plt.xticks(ind, ('G1', 'G2', 'G3', 'G4', 'G5'))
plt.yticks(np.arange(0, 81, 10))
plt.legend((p1[0], p2[0]), ('Men', 'Women'))


plt.show()

# %% [markdown]
# ### Scatter Plots

# %%
import numpy as np
import matplotlib.pyplot as plt

n=1024
x = np.random.normal(100, 30, n)
y = np.random.normal(100, 30, n)
T = np.arctan2(y, x)
plt.axes([0.025, 0.025, 0.95, 0.95])

plt.scatter(x, y, c=T, alpha=0.5)
plt.xticks(())
plt.yticks(())
plt.title("title")

plt.show()

# %% [markdown]
# ### pie chart

# %%
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]

explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes,  
        labels=labels, 
        autopct='%1.1f%%', 
        textprops=dict(color="black"), 
        explode=explode,
        shadow=True, 
        startangle=90
    )

ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title("Pie chart example", bbox={'facecolor':'0.8', 'pad':5})

ax1.legend(labels,
          title="Ingredients",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1)
    )

plt.show()

# %% [markdown]
# ### box plot

# %%
import matplotlib.pyplot as plt
import numpy as np


np.random.seed(10)
collectn_1 = np.random.normal(100, 10, 200)
collectn_2 = np.random.normal(80, 30, 200)
collectn_3 = np.random.normal(90, 20, 200)
collectn_4 = np.random.normal(70, 25, 200)

data_to_plot = [collectn_1, collectn_2, collectn_3, collectn_4]

fig = plt.figure(1, figsize=(9, 6))
ax = fig.add_subplot(111)
bp = ax.boxplot(data_to_plot)

ax.set_xticklabels(['Sample1', 'Sample2', 'Sample3', 'Sample4'])
ax.get_xaxis().tick_top()
ax.get_yaxis().tick_right()

plt.show()

# %% [markdown]
# ### text
#
# `matplotlib.pyplot.text(x, y, s, fontdict=None, withdash=<deprecated parameter>, **kwargs)[source]`
# * x, y : 字串位置
# * s : 字串
# * fontdict : 字型定義 {family, color, weight, size}

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
myfont = FontProperties(fname=r'c:\windows\fonts\kaiu.ttf')

font = {'family': 'serif',
        'color':  'darkred',
        'weight': 'normal',
        'size': 16
        }

x = np.linspace(0.0, 5.0, 100)
y = np.cos(2*np.pi*x) * np.exp(-x)

plt.plot(x, y, 'k')
plt.title('Damped exponential decay', fontdict=font)
plt.text(2, 0.65,  #字串位置
         r'$\cos(2 \pi t) \exp(-t)$',  # 字串
         fontdict=font, #字型定義
         rotation=30 #字串旋轉
    )
plt.xlabel('time (s)',fontdict=font)
plt.ylabel('voltage (mV)', fontdict=font)

# Tweak spacing to prevent clipping of ylabel
plt.subplots_adjust(left=0.15)
plt.show()

# %% [markdown]
# ## 中文字型處理
#
# 1. 設定字體絕對路徑
#
# ``` python
# from matplotlib.font_manager import FontProperties
# myfont = FontProperties(fname = r'c:\windows\fonts\kaiu.ttf')
# ```

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
myfont = FontProperties(fname=r'c:\windows\fonts\kaiu.ttf')


x = np.linspace(0.0, 5.0, 100)
y = np.cos(2*np.pi*x) * np.exp(-x)

plt.plot(x, y, 'k')
plt.title('阻尼實驗衰減關係',fontproperties=myfont, fontsize=16)
plt.text(2, 0.65,  #字串位置
        # r'$\cos(2 \pi t) \exp(-t)$',   字串
         r'阻尼數學方程式',
         fontproperties=myfont, #字型定義
         fontsize=14, #字型大小
         color="blue", #字型顏色
         rotation=30 #字串旋轉
    )
plt.xlabel('時間 (s)',fontproperties=myfont, fontsize=16)
plt.ylabel('電壓 (mV)',fontproperties=myfont, fontsize=16)

# Tweak spacing to prevent clipping of ylabel
plt.subplots_adjust(left=0.15)
plt.show()

# %% [markdown]
# 2. 設定rcParams 參數與matplotlibrc 設定檔
#
#     * 找到目前字體路徑，確認目前是抓哪個字體
#     * 首先進入matplotlibrc 預設路徑 ("'C:\Users\jc7qx\Anaconda3\lib\site-packages\matplotlib\mpl-data")
#     * 開啟 matplotlibrc 設定檔
#     * 將font.family與font.serif註解(#)移除，並在font.serif後方加入Microsoft JhengHei
#     * 刪除.matplotlib快取資料夾
#     * 放入字體至matplotlib指定字體路徑
#         * 將msj文字檔，以msj命名之，在儲存到 (C:\Users\您的使用者名稱\Anaconda3\Lib\site-packages\matplotlib\mpl-data\fonts\ttf)
#     * 使用rcParams 參數指定字體

# %%
from matplotlib.font_manager import findfont, FontProperties  
findfont(FontProperties(family=FontProperties().get_family()))
# Out:
# 'C:\\Users\\jc7qx\\Anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSans.ttf'

# %%
import matplotlib
matplotlib.matplotlib_fname()
# Out:
# 'C:\\Users\\jc7qx\\Anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\matplotlibrc'

# %%
from matplotlib.font_manager import FontProperties
import matplotlib.pyplot as plt

plt.rcParams['font.sans-serif'] = ['Microsoft JhengHei']
plt.rcParams['axes.unicode_minus'] = False

plt.plot((1,2,3),(4,3,-1))
plt.title("聲量圖")
plt.ylabel("文章數量")
plt.xlabel("品牌名稱") 
plt.show()

# %% [markdown]
# ## Seaborn

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
from scipy.stats import spearmanr
sns.set(style="white", color_codes=True)

# %%
frepie = [x/sum(frequency)*100 for x in frequency]
labels =[str(x) for x in salary]
plt.title("Pie chart for salary", bbox={'facecolor':'0.8', 'pad':5})
plt.pie(frepie, labels=labels, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1165d6978>,
# ...
#   <matplotlib.text.Text at 0x116b4bcf8>])

# %%
trade = pd.read_csv('/users/mac/desktop/yunho1.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-40-a27f9869574e> in <module>()
# ----> 1 trade = pd.read_csv('/users/mac/desktop/yunho1.csv')
#
# ...

# %%
trade.head()

# %%
g = sns.jointplot(x = "lat", y = "long", xlim=(24.995, 25.02),ylim=(121.50, 121.53),data=trade)

# %%
g = sns.jointplot(x = "lat", y = "long",xlim=(24.995, 25.02),ylim=(121.50, 121.53),data=trade, kind="scatter")

# %%
g = sns.jointplot(x = "lat", y = "long", xlim=(24.995, 25.02),ylim=(121.50, 121.53),data=trade, kind="hex")

# %%
g = sns.jointplot(x = "lat", y = "long", xlim=(24.995, 25.02),ylim=(121.50, 121.53),data=trade, kind="kde", space=0, color='g')

# %%
sns.lmplot(x="long", y = "lat",data=trade, fit_reg=False, hue="class", scatter_kws={"marker":"D", "s":30})

# %%
trade.shape

# %%
crime = [trade["long"],trade["lat"]]

# %% [markdown]
# ## Bokeh

# %%
from bokeh.io import output_file, show, output_notebook
from bokeh.models import (
  GMapPlot, GMapOptions, ColumnDataSource, Circle, Range1d, PanTool, WheelZoomTool, BoxSelectTool
)

map_options = GMapOptions(lat=25.035999, lng=121.521083, map_type="roadmap", zoom=15)

plot = GMapPlot(x_range=Range1d(), y_range=Range1d(), map_options=map_options)
plot.title.text = "台北市中正區"

# For GMaps to function, Google requires you obtain and enable an API key:
#
#     https://developers.google.com/maps/documentation/javascript/get-api-key
#
# Replace the value below with your personal API key:
plot.api_key = "AIzaSyDOt3VsxuvWT8LMjxv7YFbJ0vE211ZMw6g"

source = ColumnDataSource(
    data=dict(
        lat=[25.040345, 25.039860, 25.038092, 25.032106],
        lon=[121.511944, 121.519531, 121.524548, 121.511313],
    )
)

circle = Circle(x="lon", y="lat", size=10, fill_color="green", fill_alpha=0.8, line_color=None)
plot.add_glyph(source, circle)

plot.add_tools(PanTool(), WheelZoomTool(), BoxSelectTool())

output_file("gmap_plot.html")
show(plot)

# %%
import numpy as np

from bokeh.plotting import figure, output_file, show

# prepare some data
N = 4000
x = np.random.random(size=N) * 100
y = np.random.random(size=N) * 100
radii = np.random.random(size=N) * 1.5
colors = [
    "#%02x%02x%02x" % (int(r), int(g), 150) for r, g in zip(50+2*x, 30+2*y)
]

# output to static HTML file (with CDN resources)
output_file("color_scatter.html", title="color_scatter.py example", mode="cdn")

TOOLS="crosshair,pan,wheel_zoom,box_zoom,reset,box_select,lasso_select"

# create a new plot with the tools above, and explicit ranges
p = figure(tools=TOOLS, x_range=(0,100), y_range=(0,100))

# add a circle renderer with vectorized colors and sizes
p.circle(x,y, radius=radii, fill_color=colors, fill_alpha=0.6, line_color=None)

# show the results
show(p)

# %% [markdown]
# ### 參考資料
#
# [Scipy Notes: Matplotlib Introduction](https://scipy-lectures.org/intro/matplotlib/index.html)
#
# **Beginning Python Visualization (chapter 6)**
#
# **Scientific Computing with Python 3 (chapter 6)**
#
# Scientific Plotting with Matplotlib (A Tutorial at PyCon US 2012)
#
# Python Data Science Essentials Second Edition (chapter 6)
#
# IPython Interactive Computing and Visualization Cookbook (chapter 6)
